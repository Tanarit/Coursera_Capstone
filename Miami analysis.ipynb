# %% [markdown]
# # Location for opening a Thai restaurant in Miami analysis

# %% [markdown]
# ## A Introduction

# %% [markdown]
# ### A1. Description and background:
#
# The background of the analysis is really simple my sister which is Thai now she is working in a restaurant in Miami, Florida. In the case that she wants to start her own restaurant she might want to know which location is the best.
#
# As we all know that Miami is a big city and is one of the most popular tourist destinations in the world. To invest in opening a restaurant ,it would be very high competitive and require high investment. This analysis would help to choose a location that make the restaurant to be successful.

# %% [markdown]
# ### A2. Data Description
#
# The data that will be used in this analysis:
#  - List of neighborhoods in Miami from wikipedia
#  - data of restaurant in Miami from Foursquare

# %%
# Import library and import neighborhood data from wiki
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

res = requests.get("https://en.wikipedia.org/wiki/List_of_neighborhoods_in_Miami")
soup = BeautifulSoup(res.content,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table))

# %%
df = df[0]

# %%
df.shape
# Out:
# (26, 6)

# %%
df
# Out:
#                      Neighborhood          Demonym            Population2010  \
# 0                      Allapattah              NaN                     54289
# 1   Arts & Entertainment District              NaN                     11033
# 2                        Brickell      Brickellite                     31759
# 3                     Buena Vista              NaN                      9058
# 4                   Coconut Grove          Grovite                     20076
# 5                       Coral Way              NaN                     35062
# 6                 Design District              NaN                      3573
# 7                        Downtown       Downtowner  71,000 (13,635 CBD only)
# 8                       Edgewater              NaN                     15005
# 9                         Flagami              NaN                     50834
# 10              Grapeland Heights              NaN                     14004
# 11                Health District              NaN                      2705
# 12                   Liberty City              NaN                     19725
# 13                   Little Haiti              NaN                     29760
# 14                  Little Havana              NaN                     76163
# 15                    Lummus Park              NaN                      3027
# 16                        Midtown        Midtowner                         -
# 17                       Overtown           Towner                      6736
# 18                      Park West              NaN                      4655
# 19                      The Roads              NaN                      7327
# 20                 Upper Eastside  Upper Eastsider                     12525
# 21               Venetian Islands              NaN                       NaN
# 22                   Virginia Key              NaN                        14
# 23                   West Flagler              NaN                     31407
# 24                        Wynwood       Wynwoodian                      7277
# 25                          Miami          Miamian                    399457
#
#    Population/Km²                                  Sub-neighborhoods  \
# 0            4401                                                NaN
# 1            7948                                                NaN
# 2           14541                                      West Brickell
# 3            3540  Buena Vista East Historic District and Design ...
# 4            3091  Center Grove, Northeast Coconut Grove, Southwe...
# 5            4496  Coral Gate, Golden Pines, Shenandoah, and Silv...
# 6            3623                                                NaN
# 7           10613  Brickell, Central Business District (CBD), Dow...
# 8            6675                                                NaN
# 9            5665           Alameda, Grapeland Heights, and Fairlawn
# 10           4130                                                NaN
# 11           2148                                                NaN
# 12           3733                                                NaN
# 13           3840                      Lemon City (aka Little River)
# 14           8423  Riverside and South River Drive Historic District
# 15           3680                                                NaN
# 16              -                              Edgewater and Wynwood
# 17           3405                                      Spring Garden
# 18           3635                                                NaN
# 19           4899                                                NaN
# 20           2513  Bay Point Estates, Bayside District, Belle Mea...
# 21            NaN               Biscayne Island and San Marco Island
# 22              -                                                NaN
# 23           4428                                                NaN
# 24           2983  Wynwood Art District and Wynwood Fashion District
# 25           4687                                                NaN
#
#       Coordinates
# 0   25.815-80.224
# 1   25.799-80.190
# 2   25.758-80.193
# 3   25.813-80.192
# 4   25.712-80.257
# 5   25.750-80.283
# 6   25.813-80.193
# 7   25.774-80.193
# 8   25.802-80.190
# 9   25.762-80.316
# 10  25.792-80.258
# 11            NaN
# 12  25.832-80.225
# 13  25.824-80.191
# 14  25.773-80.215
# 15  25.777-80.201
# 16  25.807-80.193
# 17  25.787-80.201
# 18  25.785-80.193
# 19  25.756-80.207
# 20  25.830-80.183
# 21  25.791-80.161
# 22  25.736-80.155
# 23  25.775-80.243
# 24  25.804-80.199
# 25            NaN

# %% [markdown]
# ## B Data Cleaning

# %%
# Drop columns that are not used in the analysis
df = df.drop(['Demonym','Sub-neighborhoods'],axis =1)

# %%
df
# Out:
#                      Neighborhood            Population2010 Population/Km²  \
# 0                      Allapattah                     54289           4401
# 1   Arts & Entertainment District                     11033           7948
# 2                        Brickell                     31759          14541
# 3                     Buena Vista                      9058           3540
# 4                   Coconut Grove                     20076           3091
# 5                       Coral Way                     35062           4496
# 6                 Design District                      3573           3623
# 7                        Downtown  71,000 (13,635 CBD only)          10613
# 8                       Edgewater                     15005           6675
# 9                         Flagami                     50834           5665
# 10              Grapeland Heights                     14004           4130
# 11                Health District                      2705           2148
# 12                   Liberty City                     19725           3733
# 13                   Little Haiti                     29760           3840
# 14                  Little Havana                     76163           8423
# 15                    Lummus Park                      3027           3680
# 16                        Midtown                         -              -
# 17                       Overtown                      6736           3405
# 18                      Park West                      4655           3635
# 19                      The Roads                      7327           4899
# 20                 Upper Eastside                     12525           2513
# 21               Venetian Islands                       NaN            NaN
# 22                   Virginia Key                        14              -
# 23                   West Flagler                     31407           4428
# 24                        Wynwood                      7277           2983
# 25                          Miami                    399457           4687
#
#       Coordinates
# 0   25.815-80.224
# 1   25.799-80.190
# 2   25.758-80.193
# 3   25.813-80.192
# 4   25.712-80.257
# 5   25.750-80.283
# 6   25.813-80.193
# 7   25.774-80.193
# 8   25.802-80.190
# 9   25.762-80.316
# 10  25.792-80.258
# 11            NaN
# 12  25.832-80.225
# 13  25.824-80.191
# 14  25.773-80.215
# 15  25.777-80.201
# 16  25.807-80.193
# 17  25.787-80.201
# 18  25.785-80.193
# 19  25.756-80.207
# 20  25.830-80.183
# 21  25.791-80.161
# 22  25.736-80.155
# 23  25.775-80.243
# 24  25.804-80.199
# 25            NaN

# %%
# Drop rows which has no information of Population Density and Coordination
df = df.drop([11, 16, 21, 22, 25])

# %%
# Reassign values in Neighborhood Downtown
df.Population2010[7] = '71000'

# %%
# Assign type of data to integer for Population2010 and Population/Km²
df['Population2010'] = df['Population2010'].astype(int)
df['Population/Km²'] = df['Population/Km²'].astype(int)

# %%
df_sort_pop = df.sort_values(by=['Population2010'], ascending=False).head()

# %%
df_sort_pop
# Out:
#      Neighborhood  Population2010  Population/Km²    Coordinates
# 14  Little Havana           76163            8423  25.773-80.215
# 7        Downtown           71000           10613  25.774-80.193
# 0      Allapattah           54289            4401  25.815-80.224
# 9         Flagami           50834            5665  25.762-80.316
# 5       Coral Way           35062            4496  25.750-80.283

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df_sort_pop.Neighborhood, df_sort_pop.Population2010, align='center', alpha=0.5)
plt.xticks(df_sort_pop.Neighborhood)
plt.ylabel('Population')
plt.xlabel('Neighborhood')
plt.title('Top 5 population in Miami')
 
plt.show()

# %%
# Separate Coordinates to Latitude and Longitude
df['Latitude'] = ''
df['Longitude'] = ''
df = df.reset_index()
df.head()
# Out:
#    index                   Neighborhood  Population2010  Population/Km²  \
# 0      0                     Allapattah           54289            4401
# 1      1  Arts & Entertainment District           11033            7948
# 2      2                       Brickell           31759           14541
# 3      3                    Buena Vista            9058            3540
# 4      4                  Coconut Grove           20076            3091
#
#      Coordinates Latitude Longitude
# 0  25.815-80.224
# 1  25.799-80.190
# 2  25.758-80.193
# 3  25.813-80.192
# 4  25.712-80.257

# %%
# Iterate to extract values of Latitude and Longitude from Coordinates
for i in range(df.shape[0]):
    df['Latitude'][i] = df['Coordinates'][i][0:6]
    
for i in range(df.shape[0]): 
    df['Longitude'][i] = df['Coordinates'][i][6:13]
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/jupyterlab/conda/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Check result
df.head()
# Out:
#    index                   Neighborhood  Population2010  Population/Km²  \
# 0      0                     Allapattah           54289            4401
# 1      1  Arts & Entertainment District           11033            7948
# 2      2                       Brickell           31759           14541
# 3      3                    Buena Vista            9058            3540
# 4      4                  Coconut Grove           20076            3091
#
#      Coordinates Latitude Longitude
# 0  25.815-80.224   25.815   -80.224
# 1  25.799-80.190   25.799   -80.190
# 2  25.758-80.193   25.758   -80.193
# 3  25.813-80.192   25.813   -80.192
# 4  25.712-80.257   25.712   -80.257

# %%
# Drop column Coordinates
df = df.drop(['Coordinates'],axis =1)

# %%
# select columns 
df = df.iloc[:,1:]

# %%
# Assign data types
df['Latitude'] = df['Latitude'].astype(float)
df['Longitude'] = df['Longitude'].astype(float)
df['Neighborhood'] = df['Neighborhood'].astype(str)

# %%
df_pop = df.sort_values(by=['Population2010'], ascending = False )
df_pop.head(5)
# Out:
#      Neighborhood  Population2010  Population/Km²  Latitude  Longitude
# 13  Little Havana           76163            8423    25.773    -80.215
# 7        Downtown           71000           10613    25.774    -80.193
# 0      Allapattah           54289            4401    25.815    -80.224
# 9         Flagami           50834            5665    25.762    -80.316
# 5       Coral Way           35062            4496    25.750    -80.283

# %%
df_den = df.sort_values(by=['Population/Km²'], ascending = False )
df_sort_den= df_den.head(5)

# %%
df_sort_den
# Out:
#                      Neighborhood  Population2010  Population/Km²  Latitude  \
# 2                        Brickell           31759           14541    25.758
# 7                        Downtown           71000           10613    25.774
# 13                  Little Havana           76163            8423    25.773
# 1   Arts & Entertainment District           11033            7948    25.799
# 8                       Edgewater           15005            6675    25.802
#
#     Longitude
# 2     -80.193
# 7     -80.193
# 13    -80.215
# 1     -80.190
# 8     -80.190

# %%
label_x = ['Brickel', 'Downtown', 'Little Havana', 'Art&Ent.', 'Edgewater']
x_pos = np.arange(len(label_x))

plt.bar(df_sort_den.Neighborhood, df_sort_den.iloc[:,2], align='center', alpha=0.5)
plt.xticks(x_pos, label_x)
plt.ylabel('Density')
plt.xlabel('Neighborhood')
plt.title('Top 5 density in Miami')
 
plt.show()

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

# %%
address = 'Miami'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 25.7742658, -80.1936589.

# %%
# create map of toronto using latitude and longitude values
map_miami = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, neighborhood, popu, den in zip(df['Latitude'], df['Longitude'], df['Neighborhood'], df['Population2010'], df['Population/Km²']):
    label = '{}, Population: {}, Density: {}'.format(neighborhood, popu, den)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=den*0.002,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.3,
        parse_html=False).add_to(map_miami)  
    
map_miami
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Get data from Foursquare

# %%
CLIENT_ID = 'BBLJWEETWIJCLJQVRRV5IUJY1N3EVSBRAOBNNFFSW45LPM5F' # your Foursquare ID
CLIENT_SECRET = 'B1VTLXFXHUBZZ0FZLFCLIDQ2RKRTYAVTKZYAWVWNY5C2RNGW' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
#nearby function

LIMIT = 200
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&section={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
            'food')
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
df_food = getNearbyVenues(names=df['Neighborhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Allapattah
# Arts & Entertainment District
# Brickell
# Buena Vista
# Coconut Grove
# Coral Way
# Design District
# Downtown
# Edgewater
# Flagami
# Grapeland Heights
# Liberty City
# Little Haiti
# Little Havana
# Lummus Park
# Overtown
# Park West
# The Roads
# Upper Eastside
# West Flagler
# Wynwood

# %%
#check result dataframe
print(df_food.shape)
df_food.head()
# Out:
# (318, 7)
#                     Neighborhood  Neighborhood Latitude  \
# 0                     Allapattah                 25.815
# 1  Arts & Entertainment District                 25.799
# 2  Arts & Entertainment District                 25.799
# 3  Arts & Entertainment District                 25.799
# 4  Arts & Entertainment District                 25.799
#
#    Neighborhood Longitude                      Venue  Venue Latitude  \
# 0                 -80.224               Ribs On Deck       25.813065
# 1                 -80.190        Jack's Home Cooking       25.800447
# 2                 -80.190  La Provence French Bakery       25.798969
# 3                 -80.190    Plant Food + Wine Miami       25.800452
# 4                 -80.190         Ted's at YoungArts       25.797391
#
#    Venue Longitude       Venue Category
# 0       -80.224282  American Restaurant
# 1       -80.191031  American Restaurant
# 2       -80.189127    French Restaurant
# 3       -80.192805           Restaurant
# 4       -80.189204     Tapas Restaurant

# %%
df_food.groupby('Neighborhood').count()
# Out:
#                                Neighborhood Latitude  Neighborhood Longitude  \
# Neighborhood
# Allapattah                                         1                       1
# Arts & Entertainment District                     17                      17
# Brickell                                          45                      45
# Buena Vista                                       18                      18
# Coconut Grove                                      1                       1
# Coral Way                                          4                       4
# Design District                                   20                      20
# Downtown                                          39                      39
# Edgewater                                         39                      39
# Flagami                                           13                      13
# Grapeland Heights                                  1                       1
# Liberty City                                       2                       2
# Little Haiti                                      10                      10
# Little Havana                                     10                      10
# Lummus Park                                       10                      10
# Overtown                                           3                       3
# Park West                                         21                      21
# The Roads                                          5                       5
# Upper Eastside                                     4                       4
# West Flagler                                       4                       4
# Wynwood                                           51                      51
#
#                                Venue  Venue Latitude  Venue Longitude  \
# Neighborhood
# Allapattah                         1               1                1
# Arts & Entertainment District     17              17               17
# Brickell                          45              45               45
# Buena Vista                       18              18               18
# Coconut Grove                      1               1                1
# Coral Way                          4               4                4
# Design District                   20              20               20
# Downtown                          39              39               39
# Edgewater                         39              39               39
# Flagami                           13              13               13
# Grapeland Heights                  1               1                1
# Liberty City                       2               2                2
# Little Haiti                      10              10               10
# Little Havana                     10              10               10
# Lummus Park                       10              10               10
# Overtown                           3               3                3
# Park West                         21              21               21
# The Roads                          5               5                5
# Upper Eastside                     4               4                4
# West Flagler                       4               4                4
# Wynwood                           51              51               51
#
#                                Venue Category
# Neighborhood
# Allapattah                                  1
# Arts & Entertainment District              17
# Brickell                                   45
# Buena Vista                                18
# Coconut Grove                               1
# Coral Way                                   4
# Design District                            20
# Downtown                                   39
# Edgewater                                  39
# Flagami                                    13
# Grapeland Heights                           1
# Liberty City                                2
# Little Haiti                               10
# Little Havana                              10
# Lummus Park                                10
# Overtown                                    3
# Park West                                  21
# The Roads                                   5
# Upper Eastside                              4
# West Flagler                                4
# Wynwood                                    51

# %%
# one hot encoding
df_onehot = pd.get_dummies(df_food[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
df_onehot['Neighborhood'] = df_food['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [df_onehot.columns[-1]] + list(df_onehot.columns[:-1])
df_onehot = df_onehot[fixed_columns]

#intown_venues.head()
df_onehot.head()
df_onehot.columns
# Out:
# Index(['Neighborhood', 'American Restaurant', 'Arepa Restaurant',
#        'Argentinian Restaurant', 'Asian Restaurant', 'BBQ Joint', 'Bakery',
#        'Bistro', 'Brazilian Restaurant', 'Breakfast Spot', 'Burger Joint',
#        'Café', 'Caribbean Restaurant', 'Chinese Restaurant',
#        'Comfort Food Restaurant', 'Cuban Restaurant', 'Deli / Bodega', 'Diner',
#        'Donut Shop', 'Eastern European Restaurant', 'Empanada Restaurant',
#        'Fast Food Restaurant', 'Food', 'Food Court', 'Food Truck',
#        'French Restaurant', 'Fried Chicken Joint', 'Gastropub',
#        'Greek Restaurant', 'Indian Restaurant', 'Indonesian Restaurant',
#        'Italian Restaurant', 'Japanese Restaurant', 'Kosher Restaurant',
#        'Latin American Restaurant', 'Mediterranean Restaurant',
#        'Mexican Restaurant', 'Middle Eastern Restaurant',
#        'New American Restaurant', 'Peruvian Restaurant', 'Pizza Place',
#        'Poke Place', 'Restaurant', 'Salad Place', 'Sandwich Place',
#        'Seafood Restaurant', 'South American Restaurant',
#        'Southern / Soul Food Restaurant', 'Spanish Restaurant', 'Steakhouse',
#        'Sushi Restaurant', 'Taco Place', 'Tapas Restaurant',
#        'Vegetarian / Vegan Restaurant', 'Venezuelan Restaurant',
#        'Wings Joint'],
#       dtype='object')

# %%
df_grouped = df_onehot.groupby('Neighborhood').mean().reset_index()
df_grouped.head()
# Out:
#                     Neighborhood  American Restaurant  Arepa Restaurant  \
# 0                     Allapattah             1.000000          0.000000
# 1  Arts & Entertainment District             0.058824          0.000000
# 2                       Brickell             0.044444          0.000000
# 3                    Buena Vista             0.055556          0.055556
# 4                  Coconut Grove             0.000000          0.000000
#
#    Argentinian Restaurant  Asian Restaurant  BBQ Joint    Bakery  Bistro  \
# 0                0.000000          0.000000        0.0  0.000000     0.0
# 1                0.000000          0.000000        0.0  0.000000     0.0
# 2                0.044444          0.000000        0.0  0.000000     0.0
# 3                0.000000          0.055556        0.0  0.111111     0.0
# 4                0.000000          0.000000        0.0  0.000000     0.0
#
#    Brazilian Restaurant  Breakfast Spot  ...  South American Restaurant  \
# 0                   0.0        0.000000  ...                        0.0
# 1                   0.0        0.058824  ...                        0.0
# 2                   0.0        0.000000  ...                        0.0
# 3                   0.0        0.000000  ...                        0.0
# 4                   0.0        0.000000  ...                        0.0
#
#    Southern / Soul Food Restaurant  Spanish Restaurant  Steakhouse  \
# 0                              0.0            0.000000    0.000000
# 1                              0.0            0.000000    0.000000
# 2                              0.0            0.022222    0.044444
# 3                              0.0            0.000000    0.000000
# 4                              0.0            0.000000    0.000000
#
#    Sushi Restaurant  Taco Place  Tapas Restaurant  \
# 0               0.0    0.000000          0.000000
# 1               0.0    0.058824          0.117647
# 2               0.0    0.000000          0.022222
# 3               0.0    0.000000          0.000000
# 4               0.0    0.000000          0.000000
#
#    Vegetarian / Vegan Restaurant  Venezuelan Restaurant  Wings Joint
# 0                            0.0               0.000000          0.0
# 1                            0.0               0.000000          0.0
# 2                            0.0               0.022222          0.0
# 3                            0.0               0.000000          0.0
# 4                            0.0               0.000000          0.0
#
# [5 rows x 56 columns]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
venues_sorted = pd.DataFrame(columns=columns)
venues_sorted['Neighborhood'] = df_grouped['Neighborhood']

for ind in np.arange(df_grouped.shape[0]):
    venues_sorted.iloc[ind, 1:] = return_most_common_venues(df_grouped.iloc[ind, :], num_top_venues)

venues_sorted.head()
# Out:
#                     Neighborhood 1st Most Common Venue  \
# 0                     Allapattah   American Restaurant
# 1  Arts & Entertainment District           Pizza Place
# 2                       Brickell                  Café
# 3                    Buena Vista           Pizza Place
# 4                  Coconut Grove   Fried Chicken Joint
#
#      2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0  Comfort Food Restaurant     French Restaurant            Food Truck
# 1               Restaurant        Sandwich Place      Tapas Restaurant
# 2       Italian Restaurant   Japanese Restaurant                  Food
# 3       Italian Restaurant                Bakery                  Café
# 4  Comfort Food Restaurant     French Restaurant            Food Truck
#
#   5th Most Common Venue   6th Most Common Venue 7th Most Common Venue  \
# 0            Food Court                    Food  Fast Food Restaurant
# 1      Cuban Restaurant              Food Truck        Breakfast Spot
# 2            Restaurant  Argentinian Restaurant    Seafood Restaurant
# 3        Sandwich Place    Fast Food Restaurant     Indian Restaurant
# 4            Food Court                    Food  Fast Food Restaurant
#
#   8th Most Common Venue        9th Most Common Venue 10th Most Common Venue
# 0   Empanada Restaurant  Eastern European Restaurant             Donut Shop
# 1           Salad Place          American Restaurant      French Restaurant
# 2            Steakhouse            French Restaurant         Sandwich Place
# 3   Japanese Restaurant     Mediterranean Restaurant     Chinese Restaurant
# 4   Empanada Restaurant  Eastern European Restaurant             Donut Shop

# %%
venues_sorted
# Out:
#                      Neighborhood            1st Most Common Venue  \
# 0                      Allapattah              American Restaurant
# 1   Arts & Entertainment District                      Pizza Place
# 2                        Brickell                             Café
# 3                     Buena Vista                      Pizza Place
# 4                   Coconut Grove              Fried Chicken Joint
# 5                       Coral Way               Seafood Restaurant
# 6                 Design District                      Pizza Place
# 7                        Downtown               Italian Restaurant
# 8                       Edgewater                      Pizza Place
# 9                         Flagami                           Bakery
# 10              Grapeland Heights                       Restaurant
# 11                   Liberty City  Southern / Soul Food Restaurant
# 12                   Little Haiti                      Pizza Place
# 13                  Little Havana        Latin American Restaurant
# 14                    Lummus Park               Seafood Restaurant
# 15                       Overtown  Southern / Soul Food Restaurant
# 16                      Park West                       Restaurant
# 17                      The Roads    Vegetarian / Vegan Restaurant
# 18                 Upper Eastside                      Pizza Place
# 19                   West Flagler          Comfort Food Restaurant
# 20                        Wynwood                       Restaurant
#
#       2nd Most Common Venue      3rd Most Common Venue  \
# 0   Comfort Food Restaurant          French Restaurant
# 1                Restaurant             Sandwich Place
# 2        Italian Restaurant        Japanese Restaurant
# 3        Italian Restaurant                     Bakery
# 4   Comfort Food Restaurant          French Restaurant
# 5              Burger Joint                       Café
# 6            Sandwich Place         Italian Restaurant
# 7            Sandwich Place        Peruvian Restaurant
# 8                Restaurant        American Restaurant
# 9        Seafood Restaurant                Pizza Place
# 10              Wings Joint    Comfort Food Restaurant
# 11     Caribbean Restaurant                Wings Joint
# 12     Fast Food Restaurant                 Donut Shop
# 13               Taco Place                     Bakery
# 14      American Restaurant                       Food
# 15              Wings Joint    Comfort Food Restaurant
# 16                     Café        American Restaurant
# 17       Italian Restaurant  Latin American Restaurant
# 18               Food Court           Sushi Restaurant
# 19         Cuban Restaurant                     Bakery
# 20               Food Truck                       Café
#
#         4th Most Common Venue 5th Most Common Venue  \
# 0                  Food Truck            Food Court
# 1            Tapas Restaurant      Cuban Restaurant
# 2                        Food            Restaurant
# 3                        Café        Sandwich Place
# 4                  Food Truck            Food Court
# 5   Middle Eastern Restaurant           Wings Joint
# 6         Japanese Restaurant                Bakery
# 7                        Café           Pizza Place
# 8              Sandwich Place            Food Truck
# 9                        Food  Fast Food Restaurant
# 10          French Restaurant            Food Truck
# 11    Comfort Food Restaurant     French Restaurant
# 12         Italian Restaurant    Seafood Restaurant
# 13                       Café            Restaurant
# 14                  BBQ Joint    Spanish Restaurant
# 15          French Restaurant            Food Truck
# 16                 Food Truck           Pizza Place
# 17                Salad Place    Mexican Restaurant
# 18         Italian Restaurant           Wings Joint
# 19  Latin American Restaurant     French Restaurant
# 20         Mexican Restaurant   American Restaurant
#
#             6th Most Common Venue    7th Most Common Venue  \
# 0                            Food     Fast Food Restaurant
# 1                      Food Truck           Breakfast Spot
# 2          Argentinian Restaurant       Seafood Restaurant
# 3            Fast Food Restaurant        Indian Restaurant
# 4                            Food     Fast Food Restaurant
# 5                Cuban Restaurant               Food Truck
# 6                            Café     Fast Food Restaurant
# 7                Greek Restaurant     Brazilian Restaurant
# 8                  Breakfast Spot         Cuban Restaurant
# 9                      Taco Place      Peruvian Restaurant
# 10                     Food Court                     Food
# 11                     Food Truck               Food Court
# 12             Spanish Restaurant     Caribbean Restaurant
# 13             Mexican Restaurant            Deli / Bodega
# 14                          Diner               Restaurant
# 15                     Food Court                     Food
# 16                 Sandwich Place            Deli / Bodega
# 17                    Wings Joint  Comfort Food Restaurant
# 18                     Food Truck                     Food
# 19                     Food Truck               Food Court
# 20  Vegetarian / Vegan Restaurant         Asian Restaurant
#
#         8th Most Common Venue        9th Most Common Venue  \
# 0         Empanada Restaurant  Eastern European Restaurant
# 1                 Salad Place          American Restaurant
# 2                  Steakhouse            French Restaurant
# 3         Japanese Restaurant     Mediterranean Restaurant
# 4         Empanada Restaurant  Eastern European Restaurant
# 5                  Food Court                         Food
# 6           Indian Restaurant     Mediterranean Restaurant
# 7         American Restaurant    Latin American Restaurant
# 8           French Restaurant             Tapas Restaurant
# 9   Latin American Restaurant           Spanish Restaurant
# 10       Fast Food Restaurant          Empanada Restaurant
# 11                       Food         Fast Food Restaurant
# 12           Sushi Restaurant       Argentinian Restaurant
# 13                Wings Joint             Cuban Restaurant
# 14    Comfort Food Restaurant                   Food Truck
# 15       Fast Food Restaurant          Empanada Restaurant
# 16                      Diner                    Gastropub
# 17                 Food Court                         Food
# 18       Fast Food Restaurant          Empanada Restaurant
# 19                       Food         Fast Food Restaurant
# 20    New American Restaurant         Caribbean Restaurant
#
#            10th Most Common Venue
# 0                      Donut Shop
# 1               French Restaurant
# 2                  Sandwich Place
# 3              Chinese Restaurant
# 4                      Donut Shop
# 5            Fast Food Restaurant
# 6              Chinese Restaurant
# 7       Middle Eastern Restaurant
# 8                   Deli / Bodega
# 9                Cuban Restaurant
# 10    Eastern European Restaurant
# 11            Empanada Restaurant
# 12  Vegetarian / Vegan Restaurant
# 13                     Food Court
# 14                     Food Court
# 15    Eastern European Restaurant
# 16            Japanese Restaurant
# 17           Fast Food Restaurant
# 18    Eastern European Restaurant
# 19            Empanada Restaurant
# 20            Peruvian Restaurant

# %% [markdown]
# # A3. Cluster analysis

# %%
# set number of clusters
kclusters = 6

grouped_clustering = df_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 0, 0, 0, 3, 0, 0, 0, 0, 0], dtype=int32)

# %%
# add clustering labels
venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

df_merged = df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
df_merged = df_merged.join(venues_sorted.set_index('Neighborhood'), on='Neighborhood')

df_merged.head() # check the last columns!
# Out:
#                     Neighborhood  Population2010  Population/Km²  Latitude  \
# 0                     Allapattah           54289            4401    25.815
# 1  Arts & Entertainment District           11033            7948    25.799
# 2                       Brickell           31759           14541    25.758
# 3                    Buena Vista            9058            3540    25.813
# 4                  Coconut Grove           20076            3091    25.712
#
#    Longitude  Cluster Labels 1st Most Common Venue    2nd Most Common Venue  \
# 0    -80.224               1   American Restaurant  Comfort Food Restaurant
# 1    -80.190               0           Pizza Place               Restaurant
# 2    -80.193               0                  Café       Italian Restaurant
# 3    -80.192               0           Pizza Place       Italian Restaurant
# 4    -80.257               3   Fried Chicken Joint  Comfort Food Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0     French Restaurant            Food Truck            Food Court
# 1        Sandwich Place      Tapas Restaurant      Cuban Restaurant
# 2   Japanese Restaurant                  Food            Restaurant
# 3                Bakery                  Café        Sandwich Place
# 4     French Restaurant            Food Truck            Food Court
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                    Food  Fast Food Restaurant   Empanada Restaurant
# 1              Food Truck        Breakfast Spot           Salad Place
# 2  Argentinian Restaurant    Seafood Restaurant            Steakhouse
# 3    Fast Food Restaurant     Indian Restaurant   Japanese Restaurant
# 4                    Food  Fast Food Restaurant   Empanada Restaurant
#
#          9th Most Common Venue 10th Most Common Venue
# 0  Eastern European Restaurant             Donut Shop
# 1          American Restaurant      French Restaurant
# 2            French Restaurant         Sandwich Place
# 3     Mediterranean Restaurant     Chinese Restaurant
# 4  Eastern European Restaurant             Donut Shop

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster, den in zip(df_merged['Latitude'], df_merged['Longitude'], df_merged['Neighborhood'], df_merged['Cluster Labels'], df_merged['Population/Km²'] ):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=den*0.002,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_merged.loc[df_merged['Cluster Labels'] == 0, df_merged.columns[[1] + list(range(5, df_merged.shape[1]))]]
# Out:
#     Population2010  Cluster Labels 1st Most Common Venue  \
# 1            11033               0           Pizza Place
# 2            31759               0                  Café
# 3             9058               0           Pizza Place
# 5            35062               0    Seafood Restaurant
# 6             3573               0           Pizza Place
# 7            71000               0    Italian Restaurant
# 8            15005               0           Pizza Place
# 9            50834               0                Bakery
# 12           29760               0           Pizza Place
# 14            3027               0    Seafood Restaurant
# 16            4655               0            Restaurant
# 18           12525               0           Pizza Place
# 20            7277               0            Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue      4th Most Common Venue  \
# 1             Restaurant        Sandwich Place           Tapas Restaurant
# 2     Italian Restaurant   Japanese Restaurant                       Food
# 3     Italian Restaurant                Bakery                       Café
# 5           Burger Joint                  Café  Middle Eastern Restaurant
# 6         Sandwich Place    Italian Restaurant        Japanese Restaurant
# 7         Sandwich Place   Peruvian Restaurant                       Café
# 8             Restaurant   American Restaurant             Sandwich Place
# 9     Seafood Restaurant           Pizza Place                       Food
# 12  Fast Food Restaurant            Donut Shop         Italian Restaurant
# 14   American Restaurant                  Food                  BBQ Joint
# 16                  Café   American Restaurant                 Food Truck
# 18            Food Court      Sushi Restaurant         Italian Restaurant
# 20            Food Truck                  Café         Mexican Restaurant
#
#    5th Most Common Venue          6th Most Common Venue 7th Most Common Venue  \
# 1       Cuban Restaurant                     Food Truck        Breakfast Spot
# 2             Restaurant         Argentinian Restaurant    Seafood Restaurant
# 3         Sandwich Place           Fast Food Restaurant     Indian Restaurant
# 5            Wings Joint               Cuban Restaurant            Food Truck
# 6                 Bakery                           Café  Fast Food Restaurant
# 7            Pizza Place               Greek Restaurant  Brazilian Restaurant
# 8             Food Truck                 Breakfast Spot      Cuban Restaurant
# 9   Fast Food Restaurant                     Taco Place   Peruvian Restaurant
# 12    Seafood Restaurant             Spanish Restaurant  Caribbean Restaurant
# 14    Spanish Restaurant                          Diner            Restaurant
# 16           Pizza Place                 Sandwich Place         Deli / Bodega
# 18           Wings Joint                     Food Truck                  Food
# 20   American Restaurant  Vegetarian / Vegan Restaurant      Asian Restaurant
#
#         8th Most Common Venue      9th Most Common Venue  \
# 1                 Salad Place        American Restaurant
# 2                  Steakhouse          French Restaurant
# 3         Japanese Restaurant   Mediterranean Restaurant
# 5                  Food Court                       Food
# 6           Indian Restaurant   Mediterranean Restaurant
# 7         American Restaurant  Latin American Restaurant
# 8           French Restaurant           Tapas Restaurant
# 9   Latin American Restaurant         Spanish Restaurant
# 12           Sushi Restaurant     Argentinian Restaurant
# 14    Comfort Food Restaurant                 Food Truck
# 16                      Diner                  Gastropub
# 18       Fast Food Restaurant        Empanada Restaurant
# 20    New American Restaurant       Caribbean Restaurant
#
#            10th Most Common Venue
# 1               French Restaurant
# 2                  Sandwich Place
# 3              Chinese Restaurant
# 5            Fast Food Restaurant
# 6              Chinese Restaurant
# 7       Middle Eastern Restaurant
# 8                   Deli / Bodega
# 9                Cuban Restaurant
# 12  Vegetarian / Vegan Restaurant
# 14                     Food Court
# 16            Japanese Restaurant
# 18    Eastern European Restaurant
# 20            Peruvian Restaurant

# %%
df_merged.loc[df_merged['Cluster Labels'] == 4, df_merged.columns[[1] + list(range(5, df_merged.shape[1]))]]
# Out:
#     Population2010  Cluster Labels          1st Most Common Venue  \
# 13           76163               4      Latin American Restaurant
# 17            7327               4  Vegetarian / Vegan Restaurant
# 19           31407               4        Comfort Food Restaurant
#
#    2nd Most Common Venue      3rd Most Common Venue  \
# 13            Taco Place                     Bakery
# 17    Italian Restaurant  Latin American Restaurant
# 19      Cuban Restaurant                     Bakery
#
#         4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 13                       Café            Restaurant    Mexican Restaurant
# 17                Salad Place    Mexican Restaurant           Wings Joint
# 19  Latin American Restaurant     French Restaurant            Food Truck
#
#       7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 13            Deli / Bodega           Wings Joint      Cuban Restaurant
# 17  Comfort Food Restaurant            Food Court                  Food
# 19               Food Court                  Food  Fast Food Restaurant
#
#    10th Most Common Venue
# 13             Food Court
# 17   Fast Food Restaurant
# 19    Empanada Restaurant

# %% [markdown]
# # A4. Conclusion
# The best location for opening a Thai restaurant in Miami is in Brickell or Downtown which both neighborhoods have high density and they both are in cluster 0 - ‘International Food’ cluster which Thai restaurant could be a good option for those mixed culture people. In the other hand Little Havana which has the highest population and the third of highest density but it is in cluster 4 - ‘Latino Food’ it might not be a good idea to open a Thai restaurant there.
